# %%
# !pip install -q openai

# %%
import openai
import os

# %%
os.environ['OPENAI_API_KEY'] = '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'
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
prompt = "What does the start-up company Pentera do and who invested in it?"

# %%
response = openai.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0,
    max_tokens=512
)

# %%
response.choices[0].text
# Out:
# '\n\nPentera is a start-up company that specializes in developing and manufacturing advanced technology for precision agriculture. They offer a range of products and services, including sensors, software, and analytics, to help farmers optimize their crop production and reduce waste.\n\nThe company was founded in 2015 by a team of engineers and agronomists with the goal of using technology to improve the efficiency and sustainability of agriculture. They have received investments from several venture capital firms, including Khosla Ventures, Innovation Endeavors, and OurCrowd. In 2019, they also received a strategic investment from Bayer, a multinational pharmaceutical and life sciences company, to further develop their technology and expand their reach in the agriculture industry.'

# %%
import textwrap
text = response.choices[0].text.strip()
wrapped_text = textwrap.fill(text, width=100)
print(wrapped_text)
# Out:
# Pentera is a start-up company that specializes in developing and manufacturing advanced technology
# for precision agriculture. They offer a range of products and services, including sensors, software,
# and analytics, to help farmers optimize their crop production and reduce waste.  The company was
# founded in 2015 by a team of engineers and agronomists with the goal of using technology to improve
# the efficiency and sustainability of agriculture. They have received investments from several
# venture capital firms, including Khosla Ventures, Innovation Endeavors, and OurCrowd. In 2019, they
# also received a strategic investment from Bayer, a multinational pharmaceutical and life sciences
# company, to further develop their technology and expand their reach in the agriculture industry.

# %% [markdown]
# #####  This is model hallucination the investors are right but the amount is totally far away from the real one besides its not a company the provides employees benefits programs they do automated security validation

# %%
prompt = ''' Only answer the question below if you have 100% certainty of the facts.
Q: What does the start-up company Pentera do and who invested in it?
A:
'''

# %%
response = openai.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0,
    max_tokens=512
)

# %%
print(response.choices[0].text.strip())
# Out:
# I cannot answer this question as I do not have 100% certainty of the facts.

# %% [markdown]
# #### So this what we will do in Text embedding

# %%
prompt = ''' Only answer the question below if you have 100% certainty of the facts.
Context : {Context}  # embedding some documents
Q: What does the start-up company Pentera do and who invested in it?
A:
'''
